# %%
from PIL import Image
import numpy as np
import tensorflow as tf

model = tf.keras.models.load_model('models/potato_model.keras')
img = Image.open('C:\Project\Potato-Disease-Classification\traning\PlantVillage\Potato___Early_blight/0a8a68ee-f587-4dea-beec-79d02e7d3fa4___RS_Early.B 8461.jpg')
arr = preprocess_image(img)
print(model.predict(arr))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       2 import numpy as np
#       3 import tensorflow as tf
# ----> 5 model = tf.keras.models.load_model('backend/models/potato_model.keras')
#       6 img = Image.open('C:\Project\Potato-Disease-Classification\traning\PlantVillage\Potato___Early_blight/0a8a68ee-f587-4dea-beec-79d02e7d3fa4___RS_Early.B 8461.jpg')
#       7 arr = preprocess_image(img)
#
# File c:\Users\Praveen\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\saving\saving_api.py:200, in load_model(filepath, custom_objects, compile, safe_mode)
#     196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
# --> 200     raise ValueError(
# ...

# %%
import os
print(os.path.exists('models/potato_model.keras'))
# Out:
# True
